# %%
import boto3
import json
import os
from dotenv import load_dotenv

load_dotenv()

client = boto3.client(
    service_name='kinesis',
    region_name=os.getenv("AWS_REGION"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY")
)

#register = {'idseller': '997', 'name': 'Jane Damo', 'email': 'janedamo@example.com'}
register = {'idseller': '998', 'name': 'Craig Johnson', 'email': 'craigjohnson@example.com'}
#register = {'idseller': '999', 'name': 'William Smith', 'email': 'williamsmith@example.com'}

response = client.put_record(
    StreamName=os.getenv("KINESIS_STREAM_NAME"),
    Data=json.dumps(register),
    PartitionKey=os.getenv("KINESIS_PARTITION_KEY")
)

print(f"Record sent to Kinesis stream. Sequence number: {response['SequenceNumber']}")
# Out:
# Record sent to Kinesis stream. Sequence number: 49677541475508522706295537029588865334079610328604213282
